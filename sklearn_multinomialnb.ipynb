# %%
import numpy as np
import scipy #only sparse matrices allowed
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost.sklearn import XGBClassifier

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
multinomial_nb_clf = MultinomialNB()
multinomial_nb_clf.fit(X_train,y_train.ravel())
multinomial_nb_predictions = multinomial_nb_clf.predict(X_test)
multinomial_nb_accuracy = multinomial_nb_clf.score(X_test, y_test.ravel())

# %%
multinomial_nb_accuracy
# Out:
# 0.7825443786982249

# %%
#https://stackoverflow.com/questions/3518778/how-do-i-read-csv-data-into-a-record-array-in-numpy
from numpy import genfromtxt
X_test_std = genfromtxt('X_test_std.csv', delimiter=',')
X_train_ada_std = genfromtxt('X_train_ada_std.csv', delimiter=',')
X_train_std = genfromtxt('X_train_std.csv', delimiter=',')

y_test = genfromtxt('y_test.csv', delimiter=',')
y_train_ada = genfromtxt('y_train_ada.csv', delimiter=',')
y_train = genfromtxt('y_train.csv', delimiter=',')

y_test = y_test.astype(int)
y_train_ada = y_train_ada.astype(int)
y_train = y_train.astype(int)

# %% [markdown]
# # Gridsearch for best hyperparameters:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
#https://www.analyticsvidhya.com/blog/2021/06/tune-hyperparameters-with-gridsearchcv/
#https://www.mygreatlearning.com/blog/gridsearchcv/

# %%
param_grid = {
    'alpha' : [1.0, 0.8, 0.4, 0.1],
    'fit_prior' : [False, True],
}

# %%
multi_nb_clf = MultinomialNB()
grid = HalvingRandomSearchCV(estimator = multi_nb_clf, param_distributions = param_grid, refit = True, verbose = 2, n_jobs=-1, factor = 1.2)
# fitting the model for grid search 
grid.fit(X_train_ada_std, y_train_ada.ravel())
# Out:
# n_iterations: 12
# n_required_iterations: 12
# n_possible_iterations: 41
# min_resources_: 30
# max_resources_: 47997
# aggressive_elimination: False
# factor: 1.2
# ----------
# iter: 0
# n_candidates: 8
# n_resources: 30
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# C:\Users\kaush\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 8 is smaller than n_iter=1599. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\kaush\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 40 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# ...

# %%
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test_std)

# %%
print(classification_report(y_test, grid_predictions))

# %%
multi_nb_clf = MultinomialNB()
grid = HalvingRandomSearchCV(estimator = multi_nb_clf, param_distributions = param_grid, refit = True, verbose = 2, n_jobs=-1, factor = 1.2)
# fitting the model for grid search 
grid.fit(X_train_std, y_train.ravel())

# %%
# print best parameter after tuning 
print(grid.best_params_) 
grid_predictions = grid.predict(X_test_std)

# %%
print(classification_report(y_test, grid_predictions))
